# %% [markdown]
# # Objective: Look at tokenization of sentences

# %%
import tiktoken

# %%
encoding = tiktoken.encoding_for_model("gpt-4.1-mini")

# %%
sentence = 'Tokenization splits raw text into smaller units called tokens.'
tokens = encoding.encode(sentence)
tokens
# Out:
# [4421, 2860, 76848, 11428, 2201, 1511, 13679, 13306, 4358, 20290, 13]

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"{token_id} = {token_text}")
# Out:
# 4421 = Token
# 2860 = ization
# 76848 =  splits
# 11428 =  raw
# 2201 =  text
# 1511 =  into
# 13679 =  smaller
# 13306 =  units
# 4358 =  called
# 20290 =  tokens
# 13 = .

# %%
encoding.decode([1234])
# Out:
# '()\n'
